# %%
from check_files import (
    basic_layout, check_basics, compile_study_df, create_df_descriptor, process_participant_data, process_event_data,
)
import os
import json
import fnmatch
import time
import random
from glob import glob
from wordcloud import WordCloud
from collections import Counter
from bids import BIDSLayout
from bids.exceptions import BIDSConflictingValuesError, BIDSValidationError
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset_dir = '/Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/MetaData/openneuro_cloned/openneuro'
open_neuro_id = 'ds004917'

# %%
basic_layout(dataset_dir, open_neuro_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 basic_layout(dataset_dir, open_neuro_id)
#
# File ~/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/MetaData/openneuro_scrub/scripts/check_files.py:20, in basic_layout(root_dir, study)
#       9 def basic_layout(root_dir: str, study: str) -> BIDSLayout:
#      10     """
#      11     Create a BIDSLayout object for a given study.
#      12
#    (...)
#      18     BIDSLayout: A BIDSLayout object for the specified study.
#      19     """
# ---> 20     study_path = os.path.join(root_dir,open_id)
#      21     bids_layout = BIDSLayout(study_path)
#      22     tasks = bids_layout.get_tasks()
#
# NameError: name 'open_id' is not defined

# %%
compile_study_df(open_id, layout, subs, tasks, runs, sessions)
# Out:
#     open_id  num_subs  num_tasks  num_runs  num_sessions  max_sessions  \
# 0  ds004917        53          1         0             1             0
#
#    min_sessions  tasks nonrest_tasks  nifti_exists  dwi_exists  t1w_exists  \
# 0             0  [pdm]         [pdm]             1           1           1
#
#    t2w_exists  bold_exists  events_exists
# 0           1            1              1

# %%
# Convert dataset description to a DataFrame, including study_id
df_descriptor = pd.DataFrame([
    {"study_id": open_id, "key": key, "value": value} 
    for key, value in layout.get_dataset_description().items()
])

return df_descriptor
# Out:
#     study_id                 key  \
# 0   ds004917                Name
# 1   ds004917         BIDSVersion
# 2   ds004917         DatasetType
# 3   ds004917             License
# 4   ds004917    Acknowledgements
# 5   ds004917    HowToAcknowledge
# 6   ds004917      SourceDatasets
# 7   ds004917          HEDVersion
# 8   ds004917             Funding
# 9   ds004917             Authors
# 10  ds004917  ReferencesAndLinks
# 11  ds004917     EthicsApprovals
# 12  ds004917          DatasetDOI
#
#                                                 value
# 0     Probability Decision-making Task with ambiguity
# 1                                               1.9.0
# 2                                                 raw
# 3                                                 CC0
# 4
# 5   If using this dataset, please cite the followi...
# 6   [{'DOI': '10.18112/openneuro.ds004917.v1.0.0',...
# 7
# 8   [ANID FONDECYT 11140535, ANID FONDECYT 1181295...
# 9   [Alejandra Figueroa-Vargas, Gabriela Valdebeni...
# 10  [GitHub repository: https://github.com/neuroci...
# 11  [IRB #2020-67 Comite Etico Cientifico, Univers...
# 12             doi:10.18112/openneuro.ds004917.v1.0.1

# %%
df = pd.read_csv(layout.get(suffix="participants", extension="tsv", return_type="file")[0], sep='\t')
# Convert columns into key-value pairs
df_long = pd.DataFrame([
    {"study_id": open_id, "key": col, "value": row[col]}
    for _, row in df.iterrows()
    for col in df.columns if col != "study_id"
])

json_keys = set(json.load(open(
    layout.get(suffix="participants", extension="json", return_type="file")[0])) if layout.get(
        suffix="participants", extension="json", return_type="file"
        ) else {}
        )

# Add a column indicating if the key exists in JSON
df_long["eventkeys_in_json"] = df_long["key"].isin(json_keys).astype(int)

print(df_long)
# Out:
#      study_id             key         value  eventkeys_in_json
# 0    ds004917  participant_id        sub-01                  0
# 1    ds004917          specie  homo sapiens                  1
# 2    ds004917             age            20                  1
# 3    ds004917             sex             M                  1
# 4    ds004917             T1w             T                  1
# ..        ...             ...           ...                ...
# 472  ds004917             T1w             T                  1
# 473  ds004917             T2w             T                  1
# 474  ds004917             dwi             F                  1
# 475  ds004917            func             F                  1
# 476  ds004917             eeg             T                  1
#
# [477 rows x 4 columns]

# %%
df = pd.read_csv(layout.get(task=tasks[0], suffix="events", extension="tsv", return_type="file")[0], sep='\t')
df_long = pd.DataFrame([
    {"study_id": open_id, "task": tasks[0], "key": col, "value": row[col]}
    for _, row in df.iterrows()
    for col in df.columns if col != "study_id"
])

json_keys = set(json.load(open(
    layout.get(task=tasks[0], suffix="events", extension="json", return_type="file")[0])) if layout.get(
        task=tasks[0], suffix="events", extension="json", return_type="file"
        ) else {}
        )

# Add a column indicating if the key exists in JSON
df_long["eventkeys_in_json"] = df_long["key"].isin(json_keys).astype(int)

print(df_long)
# Out:
#       study_id task       key    value  eventkeys_in_json
# 0     ds004917  pdm     onset   2.8084                  1
# 1     ds004917  pdm  duration   1.0000                  1
# 2     ds004917  pdm     value   9.0000                  1
# 3     ds004917  pdm  response -99.0000                  1
# 4     ds004917  pdm        rt -99.0000                  1
# ...        ...  ...       ...      ...                ...
# 1975  ds004917  pdm         a      NaN                  1
# 1976  ds004917  pdm      bias      NaN                  1
# 1977  ds004917  pdm         p      NaN                  1
# 1978  ds004917  pdm        pv      NaN                  1
# 1979  ds004917  pdm     ronda      NaN                  1
#
# [1980 rows x 5 columns]

# %%
studies = ["ds004917", "ds004926", "ds004884"]
all_dfs = []  # List to store individual DataFrames

for study in studies:
    open_id = study
    files_to_check = ["CHANGES", "README", "README.txt", "participants.json", "participants.tsv", "dataset_description.json"]

    path = f'/Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/MetaData/openneuro_cloned/openneuro/{open_id}'
    layout = BIDSLayout(path)
    
    tasks = layout.get_tasks()
    non_rest = [task for task in tasks if task != "rest"]
    
    if non_rest:
        for task in non_rest:
            files_to_check.extend([
                f"task-{task}_events.json",
                f"task-{task}_events.tsv",
                f"task-{task}_bold.json",
            ])

    file_status = [
        "Top" if layout.get_file(file) 
        else "func" if any(layout.get(task=task, suffix="events", extension="tsv", return_type="file")) and any(f"task-{task}" in file for task in non_rest) 
        else "Missing"
        for file in files_to_check
    ]

    df = pd.DataFrame({"study_id": open_id, "file": files_to_check, "location": file_status})
    all_dfs.append(df)  # Append each DataFrame to the list

# Concatenate all DataFrames into one
final_df = pd.concat(all_dfs, ignore_index=True)
final_df["status"] = np.where(final_df["location"] == "Missing", 0, 1)

final_df
# Out:
#     study_id                       file location  status
# 0   ds004917                    CHANGES      Top       1
# 1   ds004917                     README      Top       1
# 2   ds004917          participants.json      Top       1
# 3   ds004917           participants.tsv      Top       1
# 4   ds004917   dataset_description.json      Top       1
# 5   ds004917       task-pdm_events.json      Top       1
# 6   ds004917        task-pdm_events.tsv     func       1
# 7   ds004917         task-pdm_bold.json     func       1
# 8   ds004926                    CHANGES      Top       1
# 9   ds004926                     README      Top       1
# 10  ds004926          participants.json  Missing       0
# 11  ds004926           participants.tsv      Top       1
# 12  ds004926   dataset_description.json      Top       1
# 13  ds004926      task-heat_events.json     func       1
# 14  ds004926       task-heat_events.tsv     func       1
# 15  ds004926        task-heat_bold.json      Top       1
# 16  ds004884                    CHANGES      Top       1
# 17  ds004884                     README  Missing       0
# 18  ds004884          participants.json      Top       1
# 19  ds004884           participants.tsv      Top       1
# 20  ds004884   dataset_description.json      Top       1
# 21  ds004884  task-naming40_events.json     func       1
# 22  ds004884   task-naming40_events.tsv      Top       1
# 23  ds004884    task-naming40_bold.json      Top       1

# %%
layout.get_dataset_description()
# Out:
# {'BIDSVersion': '1.0.0',
#  'Name': 'Memory and decision making dataset',
#  'Description': 'These data were published in Bakkour et al. eLife, 2019',
#  'Authors': ['Akram Bakkour', 'Daphna Shohamy', 'Michael N. Shadlen'],
#  'License': 'CC0',
#  'HowToAcknowledge': 'Bakkour, A., Palombo, D.J., Zylberberg, A., Kang,Y.H.R., Reid, A., Verfaellie, M., Shadlen,M.N., Shohamy, D. (2019). The hippocampus supports deliberation during value based decisions. eLife. [eprint].',
#  'Funding': 'McKnight Memory and Cognitive Disorders Award',
#  'DatasetDOI': '10.18112/openneuro.ds002006.v1.0.1'}

# %%
file_existence_df = create_file_existence_df(outdata, files_to_check)
# Out:
# <BIDSDataFile filename='/Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/MetaData/outdata/ds002006/participants.tsv'> exists

# %% [markdown]
# ## Define Some functions

# %%
def check_columns_in_events(sub_event_df, data_task_descriptor):
    assert isinstance(sub_event_df, pd.DataFrame), "sub_event_df should be a pandas DataFrame"
    assert isinstance(data_task_descriptor, dict), "data_task_descriptor should be a dictionary"

    results = []

    for events_cols in sub_event_df.columns:
        col_type = "neither"
        exists_in_data = events_cols in data_task_descriptor.keys()
        
        # check if col in task .json in root
        if exists_in_data:
            # is col numeric/int/float or str/object
            if pd.api.types.is_object_dtype(sub_event_df[events_cols]):
                col_type = "object"
                
                # categorical should have levels associated to describe
                if 'Levels' not in data_task_descriptor[events_cols]:
                    levels_check = "Levels key missing in data descriptor"

                    # each levels will have 1=+ values, get unique
                    try:
                        unique_values = sub_event_df[events_cols].unique()
                    except Exception as e:
                        unique_values = []
                        levels_check = f"Could not get unique values from column {events_cols}: {e}"

                    # add to running list
                    for check in unique_values:
                        results.append({
                            'events_column': events_cols,
                            'string_unique': check,
                            'data_type': col_type,
                            'column_in_descriptor': exists_in_data,
                            'string_unique_in_levels': levels_check
                        })
                else:
                    # each levels will have 1=+ values, get unique
                    try:
                        unique_values = sub_event_df[events_cols].unique()
                    except Exception as e:
                        unique_values = []
                        levels_check = f"Could not get unique values from column {events_cols}: {e}"
                    
                    # sometimes categorical variables written as uppercase but levels may be lowercase
                    lower_keys = {k.lower() for k in data_task_descriptor[events_cols]['Levels'].keys()}
                    
                    # is string in columns in levels
                    levels_check = []
                    for string_val in unique_values:
                        if isinstance(string_val, str) and string_val.lower() in lower_keys:
                            levels_check.append(f"{string_val}: Exists in Levels")
                        else:
                            levels_check.append(f"{string_val}: Missing from Levels")
                
                    # add to running list
                    for check in levels_check:
                        results.append({
                            'events_column': events_cols,
                            'string_unique': check.split(':')[0],
                            'data_type': col_type,
                            'column_in_descriptor': exists_in_data,
                            'string_unique_in_levels': check
                        })
                
            elif pd.api.types.is_numeric_dtype(sub_event_df[events_cols]):
                col_type = "numeric"
                
                # same as above, but doing numeric dtype check
                results.append({
                    'events_column': events_cols,
                    'string_unique': None,  # No unique value for numeric columns *confirm if studies uses numeric for categories*
                    'data_type': col_type,
                    'column_in_descriptor': exists_in_data,
                    'string_unique_in_levels': None  # No levels check for numeric
                })
        else:
            # events column not in data descriptor, still add none info
            results.append({
                'events_column': events_cols,
                'string_unique': None,
                'data_type': col_type,
                'column_in_descriptor': exists_in_data,
                'string_unique_in_levels': None
            })

    return pd.DataFrame(results)


def create_file_existence_df(root_dir, files):
    dfs = []
    folder_data = []
    for study_name in opne_folders:
        for file_name in ["participants.json", "participants.tsv", "dataset_description.json"]:
            folder_data.append({
                        'dataset': os.path.basename(study_name),
                        'type': file_name,
                        'exists': file_name in os.listdir(study_name)
                })
            
            df = pd.DataFrame(folder_data)
        dfs.append(df)
    
    final_df = pd.concat(dfs, ignore_index=True)
    final_df = final_df[~final_df['dataset'].str.contains('outdata', case=False, na=False)]
    return final_df

def participant_col_list(file_list):
    col_list_df = pd.DataFrame(columns=['study_id', 'column_name'])

    for file in file_list:
        study_id = file.split('/')[-2]
        
        try:
            dat = pd.read_csv(file, sep='\t', encoding='utf-8')
        except Exception:
            try:
                dat = pd.read_csv(file, sep='\t', on_bad_lines='warn')
            except Exception:
                dat = pd.read_csv(file, sep='\t', encoding='ISO-8859-1')
        
        data_rows = [{'study_id': study_id, 'column_name': col} for col in dat.columns]

        col_list_df = pd.concat([col_list_df, pd.DataFrame(data_rows)], ignore_index=True)
    
    return col_list_df

def participant_col_values(file_list, col_list):
    results_df = pd.DataFrame(columns=['study_id', 'column_name', 'values'])

    # lowercase for case-insensitive matching
    columns_lowcase = [col.lower() for col in col_list]

    for file in file_list:
        study_id = file.split('/')[-2]
        
        try:
            dat = pd.read_csv(file, sep='\t', encoding='utf-8')
        except Exception:
            try:
                dat = pd.read_csv(file, sep='\t', on_bad_lines='warn')
            except Exception:
                dat = pd.read_csv(file, sep='\t', encoding='ISO-8859-1')
        
        # column names to lowercase for case-insensitive comparison
        columns_lower = {col.lower(): col for col in dat.columns}
        
        # get matching upper/lower cols
        matching_columns = set(columns_lowcase) & set(columns_lower.keys())
        
        for col_lower in matching_columns:
            actual_col_name = columns_lower[col_lower]
            values = dat[actual_col_name].tolist() 
            
            # add row to df
            data_rows = [{'study_id': study_id, 
                          'column_name': actual_col_name, 
                          'values': value} for value in values]
            
            results_df = pd.concat([results_df, pd.DataFrame(data_rows)], ignore_index=True)
    
    return results_df

# %%
def get_descriptor_data(bids_path, task_name):
    descriptor_file = os.path.join(bids_path, f'task-{task_name}_events.json')
    if os.path.exists(descriptor_file):
        with open(descriptor_file, 'r') as file:
            descriptor_data = json.load(file)
            
        return True, descriptor_data 
    else:
        return False, None
    
def exist_datadesc_part_files(bids_path):

    part_json = os.path.exists(f'{bids_path}/participants.json')
    part_tsv = os.path.exists(f'{bids_path}/participants.tsv')
    datadesc_json = os.path.exists(f'{bids_path}/dataset_description.json')

    return datadesc_json, part_json, part_tsv

def exist_bold_nonrest(bids_layout):
    # does BOLD data exist, if not, skip.
    files = bids_layout.get(suffix='bold', extension='.nii.gz')
    if not files: 
        return False, None
    
    # are non-rest tasks present?
    list_tasks = bids_layout.get_tasks()
    if all(task in ['rest', 'resting'] for task in list_tasks):
        return True, False
    
    return True, True
        

def extract_info_from_path(path):
    base_file_noext = os.path.splitext(os.path.basename(path))[0]
    sub_parts = base_file_noext.split('_')
    
    # extract sub-, ses-, task-, and run- info details
    sub_id = next((part.split('-')[1] for part in sub_parts if part.startswith('sub-')), None)
    ses_num = next((part.split('-')[1] for part in sub_parts if part.startswith('ses-')), None)
    task_lab = next((part.split('-')[1] for part in sub_parts if part.startswith('task-')), None)
    run_num = next((part.split('-')[1] for part in sub_parts if part.startswith('run-')), None)
    
    return sub_id, ses_num, task_lab, run_num


def get_events_df(bids_layout, sub, task, sess=None, run=None):
    time.sleep(1)

    kwargs = {'subject': sub, 'task': task, 'suffix': 'events', 'extension': '.tsv', 'return_type': 'filename'}
    if sess is not None:
        kwargs['session'] = sess
    if run is not None:
        kwargs['run'] = run
    
    try:
        result = bids_layout.get(**kwargs)
        
        if not result or len(result) == 0:
            return None
        
        print(f"File retrieved for {kwargs}")
        file_path = result[0]
        return pd.read_csv(file_path, sep='\t')
    
    except Exception as e:
        print(f"Error retrieving or reading file for {kwargs}: {e}")
        return None


def process_events(pd_events, study_id, taskname, subj_id, sess_id, run_id, task_descriptor_info):
    if pd_events is not None:
        try:
            events_vals = check_columns_in_events(sub_event_df=pd_events, data_task_descriptor=task_descriptor_info)
            events_vals['study'] = study_id
            events_vals['subject'] = subj_id
            events_vals['session'] = sess_id
            events_vals['run'] = run_id
            events_vals['task'] = taskname
            return events_vals
        except Exception as e:
            print(f"Error processing events data")
    else:
        print(f"No File Present")

# %% [markdown]
# # 1. Availability of three primary files

# %%
outdata ='/Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro'
opne_folders = glob(f'{outdata}/*')
len(opne_folders)
# Out:
# 1109

# %%
files_to_check = ["participants.json", "participants.tsv", "dataset_description.json"]

file_existence_df = create_file_existence_df(outdata, files_to_check)

# Save the DataFrame to a CSV file
file_existence_df.to_csv('file_existence_summary.csv', index=False)

# %%
percent_type = file_existence_df.groupby('type')['exists'].mean() * 100
percent_type = percent_type.reset_index()
percent_type.columns = ['type','percent']
plt.bar(percent_type['type'], percent_type['percent'])
plt.xlabel('')
plt.ylabel('Percentage Exists (%)')
plt.title(f'Percentage of Folders Containing Each File Type \n {len(opne_folders)} OpenNeuro Datasets')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 100)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Column Types and Frequency in Participants.tsv

# %%
file_list = glob(f'{outdata}/**/participants.tsv')
len(file_list)
# Out:
# 848

# %%
columns_df = participant_col_list(file_list)
# Out:
# b'Skipping line 14: expected 16 fields, saw 17\n'
# b'Skipping line 14: expected 16 fields, saw 17\n'

# %% [markdown]
# ### Word cloud of words in columns

# %%
freq_words = Counter(columns_df['column_name'])

wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate_from_frequencies(freq_words)

# Plot the Word Cloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title(f'OpenNeuro: Wordcloud of column names \n in {len(file_list)} participants.tsv files ')
plt.show()

# %% [markdown]
# ### Frequency of words for the top 20 words

# %%
freq_words = Counter(columns_df['column_name'])

# pick top 25
top_25_words = dict(freq_words.most_common(20))
top_words_df = pd.DataFrame(list(top_25_words.items()), columns=['name', 'freq'])


plt.figure(figsize=(12, 8))
sns.barplot(data=top_words_df, y='name', x='freq', palette='viridis')
plt.title(f'Top 20 Words across \n {len(file_list)} OpenNeuro participant.tsv files')
plt.xlabel('Freq (N)')
plt.ylabel('Column Name')
plt.show()

# %% [markdown]
# # 3. Types of Values for primary columns

# %%
columns_name_eval = ['age','sex','gender','handedness','hand']
columns_values_df = participant_col_values(file_list,columns_name_eval)
# Out:
# b'Skipping line 14: expected 16 fields, saw 17\n'
# b'Skipping line 14: expected 16 fields, saw 17\n'

# %%
sex_values = columns_values_df[columns_values_df['column_name']=='sex']
gender_values = columns_values_df[columns_values_df['column_name']=='gender']
handedness = columns_values_df[columns_values_df['column_name']=='handedness']

# %% [markdown]
# ### Frequncy of values for sex/Sex columns

# %%
freq_words = Counter(sex_values['values'])

# pick top 40
top_40_words = dict(freq_words.most_common(40))

top_words_df = pd.DataFrame(list(top_40_words.items()), columns=['name', 'freq'])

#plt 
plt.figure(figsize=(12, 8))
sns.barplot(data=top_words_df, y='name', x='freq', palette='viridis')
plt.title(f'Inputs to Sex/sex columns \n {len(file_list)} OpenNeuro participant.tsv files')
plt.xlabel('Freq (N)')
plt.ylabel('Inputs')
plt.show()

# %% [markdown]
# ### Frequncy of values for Gender/gender columns

# %%
freq_words = Counter(gender_values['values'])

# pick top 30
top_30_words = dict(freq_words.most_common(30))

top_words_df = pd.DataFrame(list(top_30_words.items()), columns=['name', 'freq'])

#plt 
plt.figure(figsize=(12, 8))
sns.barplot(data=top_words_df, y='name', x='freq', palette='viridis')
plt.title(f'Inputs to Gender/gender columns \n {len(file_list)} OpenNeuro participant.tsv files')
plt.xlabel('Freq (N)')
plt.ylabel('Inputs')
plt.show()

# %% [markdown]
# ### Frequncy of values for Handedness/handedness columns

# %%
freq_words = Counter(handedness['values'])

top_20_words = dict(freq_words.most_common(20))

top_words_df = pd.DataFrame(list(top_20_words.items()), columns=['name', 'freq'])

#plt 
plt.figure(figsize=(12, 8))
sns.barplot(data=top_words_df, y='name', x='freq', palette='viridis')
plt.title(f'Inputs to handedness/Handedness columns \n {len(file_list)} OpenNeuro participant.tsv files')
plt.xlabel('Freq (N)')
plt.ylabel('Inputs')
plt.show()

# %% [markdown]
# ### Inspecting `int` when Expecting `str`

# %% [markdown]
# A number of the string variables, such as sex, gender and handedness, have intergers included. Is this a coding error on my part or a data issue?

# %%
gender_values[gender_values['values'].apply(lambda x: isinstance(x, int))].sort_values('values')
# Out:
#        study_id column_name values
# 18740  ds003424      gender      0
# 56299  ds004186      gender      0
# 56300  ds004186      gender      0
# 56301  ds004186      gender      0
# 56302  ds004186      gender      0
# ...         ...         ...    ...
# 58163  ds003357      gender     38
# 58154  ds003357      gender     46
# 58176  ds003357      gender     51
# 58157  ds003357      gender     52
# 58182  ds003357      gender     53
#
# [3118 rows x 3 columns]

# %% [markdown]
# Reviewing the above dataset `ds003357`, as it is [available on OpenNeuro](https://openneuro.org/datasets/ds003357/versions/1.0.0/file-display/participants.tsv) there are column names/labels that are flipped. For example gender <--> age. Which is a think that occurs in some other datasets, too.

# %%
pd.read_csv('/Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/MetaData/outdata/ds003357/participants.tsv',
            sep='\t')
# Out:
#    participant_id        group  gender age
# 0          sub-01  biofeedback      31   F
# 1          sub-02  biofeedback      22   F
# 2          sub-03  biofeedback      25   F
# 3          sub-04  biofeedback      46   M
# 4          sub-05  biofeedback      27   F
# 5          sub-06  biofeedback      23   M
# 6          sub-07  biofeedback      52   M
# 7          sub-08  biofeedback      29   M
# 8          sub-09  biofeedback      27   M
# 9          sub-10  biofeedback      32   F
# 10         sub-11  biofeedback      27   M
# 11         sub-12  biofeedback      22   M
# 12         sub-13  biofeedback      38   F
# 13         sub-14  biofeedback      22   F
# 14         sub-15  biofeedback      30   F
# 15         sub-16      control      26   M
# 16         sub-17      control      31   M
# 17         sub-18      control      22   M
# 18         sub-19      control      25   F
# 19         sub-20      control      24   F
# 20         sub-21      control      24   F
# 21         sub-22      control      30   F
# 22         sub-23      control      20   F
# 23         sub-24      control      20   F
# 24         sub-25      control      20   F
# 25         sub-26      control      51   M
# 26         sub-27      control      30   F
# 27         sub-28      control      28   M
# 28         sub-29      control      29   F
# 29         sub-30      control      29   M
# 30         sub-31      control      18   M
# 31         sub-32      control      53   M

# %% [markdown]
# ## Checking File Contents & Sub/Run/Sess Ns

# %%
dir_list = glob('/Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/*/')
len(dir_list)
# Out:
# 1109

# %%
study_info_general = []
combined_dataframes = []
counter = 0

for study_dir in dir_list:
    counter = counter + 1
    print('#',counter, study_dir)

    study_name = os.path.basename(os.path.dirname(study_dir))
    datadesc_exist, partjson_exist, parttsv_exist = exist_datadesc_part_files(os.path.dirname(study_dir))
    try:
        layout_study = BIDSLayout(study_dir)
        study_subs = layout_study.get_subjects()
        study_tasks = layout_study.get_tasks()
        study_runs = layout_study.get_runs()
        study_sess = layout_study.get_sessions()
        bold_exist, nonrest_exist= exist_bold_nonrest(
            bids_layout=layout_study
        )

        study_tasks_nonrest = [task for task in layout_study.get_tasks() if task not in ['rest', 'resting']]


        task_labels_list = []
        descriptor_exists_list = []

        if nonrest_exist:
            for tasklab in study_tasks_nonrest:
                descriptor_exists, descriptor_data = get_descriptor_data(bids_path=study_dir,
                                                                        task_name = tasklab)
                task_labels_list.append(tasklab)
                descriptor_exists_list.append(descriptor_exists)

                if descriptor_exists:
                    for sub in study_subs:
                        sub_events_list = layout_study.get(subject=sub, task=tasklab, suffix= 'events', extension= '.tsv', 
                                                        return_type='filename')
                        for sub_file in sub_events_list:
                            _,ses_num,_,run_num = extract_info_from_path(sub_file[0])
                            sub_events_df = pd.read_csv(sub_file, sep='\t')

                            check_eventstaskdesc_pd = process_events(pd_events=sub_events_df, task_descriptor_info=descriptor_data,
                                                                    study_id=study_name, taskname=tasklab,
                                                                    subj_id=sub, sess_id=ses_num, run_id=run_num)
                            
                            combined_dataframes.append(check_eventstaskdesc_pd)
        

        study_info_general.append({
                            'study_name': study_name,
                            'num_subs': len(study_subs) if study_subs else None,
                            'num_sess': len(study_sess) if study_sess else "1",
                            'num_runs': len(study_runs) if study_runs else "1",
                            'bold_exists': bold_exist,
                            'nonrest_exists': nonrest_exist,
                            'num_non-rest_tasks': len(study_tasks_nonrest) if study_tasks_nonrest else None,
                            'task_list': task_labels_list if task_labels_list else None,
                            'task_decsriptor_exist': descriptor_exists_list if descriptor_exists_list else None, 
                            'datadesc_exist': datadesc_exist,
                            'partic_json_exist': partjson_exist,
                            'participant_tsv_exist': parttsv_exist,
                            'error_messages': None,
                        })
    except (OSError, BIDSConflictingValuesError, BIDSValidationError, UnicodeDecodeError) as e:
        print("Error for study:", study_name)
        study_info_general.append({
                            'study_name': study_name,
                            'num_subs': None,
                            'nuum_sess': None,
                            'num_runs': None,
                            'bold_exists': None,
                            'nonrest_exists': None,
                            'num_non-rest_tasks': None,
                            'task_list': None,
                            'task_decsriptor_exist': None, 
                            'datadesc_exist': None,
                            'partic_json_exist': None,
                            'participant_tsv_exist': None,
                            'error_messages': str(e).replace('\t', '').replace(',', '') # to avoid csv/tsv parse issues
                        })
# Out:
# # 1 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003799/
# # 2 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004910/
# # 3 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002674/
# # 4 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001653/
# # 5 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003104/
# # 6 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001461/
# # 7 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002680/
# # 8 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003752/
# # 9 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004577/
# # 10 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001839/
# # 11 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004745/
# # 12 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004917/
# # 13 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004789/
# Error for study: ds004789
# # 14 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004742/
# # 15 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002687/
# # 16 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004114/
# # 17 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003103/
# # 18 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004584/
# # 19 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004579/
# # 20 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003338/
# # 21 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004122/
# # 22 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001450/
# # 23 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003763/
# # 24 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002013/
# # 25 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004926/
# # 26 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003569/
# # 27 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002014/
# # 28 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005003/
# # 29 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000115/
# # 30 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004787/
# # 31 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003764/
# # 32 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004317/
# # 33 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004125/
# # 34 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002040/
# # 35 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003192/
# # 36 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002424/
# # 37 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004515/
# # 38 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003354/
# # 39 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001890/
# # 40 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002843/
# # 41 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003965/
# # 42 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004718/
# # 43 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004512/
# # 44 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004720/
# # 45 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003505/
# # 46 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003195/
# # 47 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004182/
# # 48 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005050/
# # 49 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003708/
# # 50 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002844/
# # 51 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001299/
# # 52 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003701/
# # 53 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001600/
# # 54 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004386/
# # 55 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000170/
# # 56 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004943/
# # 57 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002886/
# # 58 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005059/
# Error for study: ds005059
# # 59 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002872/
# # 60 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001297/
# # 61 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002620/
# # 62 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002076/
# # 63 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004381/
# # 64 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005095/
# # 65 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004147/
# Error for study: ds004147
# # 66 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001607/
# # 67 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004711/
# # 68 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000148/
# # 69 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003739/
# # 70 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004944/
# # 71 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003568/
# # 72 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002218/
# # 73 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004786/
# # 74 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000114/
# # 75 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003791/
# # 76 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002643/
# # 77 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004920/
# # 78 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000113/
# # 79 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004123/
# # 80 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003550/
# # 81 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004775/
# # 82 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002672/
# # 83 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003592/
# # 84 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003754/
# # 85 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004743/
# # 86 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004327/
# # 87 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds
/Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004798/
# # 1000 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002033/
# # 1001 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004592/
# # 1002 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002691/
# # 1003 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001226/
# # 1004 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003929/
# # 1005 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004330/
# # 1006 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004102/
# # 1007 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004169/
# # 1008 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003989/
# # 1009 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003717/
# # 1010 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004532/
# # 1011 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004738/
# # 1012 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004952/
# # 1013 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005048/
# # 1014 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002609/
# # 1015 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002094/
# # 1016 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003146/
# # 1017 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003374/
# # 1018 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004151/
# # 1019 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005083/
# # 1020 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003710/
# # 1021 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003522/
# # 1022 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003380/
# # 1023 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005077/
# # 1024 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004158/
# # 1025 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001618/
# # 1026 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000168/
# # 1027 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003987/
# # 1028 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004731/
# # 1029 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003170/
# # 1030 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001415/
# Error for study: ds001415
# # 1031 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003342/
# # 1032 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000157/
# # 1033 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005079/
# # 1034 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001875/
# # 1035 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003148/
# # 1036 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003974/
# # 1037 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004194/
# # 1038 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003345/
# # 1039 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004504/
# # 1040 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003721/
# # 1041 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003570/
# # 1042 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004103/
# # 1043 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003114/
# # 1044 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003928/
# # 1045 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004331/
# # 1046 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005025/
# # 1047 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000133/
# # 1048 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001218/
# # 1049 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003789/
# # 1050 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004594/
# # 1051 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002809/
# # 1052 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001482/
# # 1053 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002207/
# # 1054 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004560/
# # 1055 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003745/
# # 1056 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004752/
# # 1057 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003548/
# # 1058 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002655/
# # 1059 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003787/
# # 1060 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000102/
# # 1061 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004556/
# # 1062 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001818/
# # 1063 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001229/
# # 1064 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004569/
# # 1065 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004909/
# # 1066 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003774/
# # 1067 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004551/
# # 1068 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004797/
# # 1069 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000105/
# # 1070 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002236/
# # 1071 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004962/
# # 1072 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004996/
# # 1073 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004398/
# # 1074 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002898/
# # 1075 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003176/
# # 1076 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001621/
# # 1077 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004161/
# # 1078 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004505/
# # 1079 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003720/
# # 1080 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004737/
# # 1081 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002606/
# # 1082 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005047/
# # 1083 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001619/
# # 1084 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003972/
# # 1085 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004965/
# # 1086 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005040/
# # 1087 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004192/
# # 1088 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds001242/
# # 1089 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004730/
# # 1090 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004502/
# # 1091 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004166/
# Error for study: ds004166
# # 1092 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003343/
# # 1093 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003171/
# # 1094 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002862/
# # 1095 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002608/
# # 1096 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002896/
# # 1097 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003944/
# # 1098 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003381/
# # 1099 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004998/
# # 1100 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004362/
# # 1101 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004706/
# Error for study: ds004706
# # 1102 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003523/
# # 1103 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003711/
# # 1104 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds000158/
# # 1105 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003716/
# # 1106 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds004533/
# # 1107 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003524/
# # 1108 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds005085/
# # 1109 /Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds003988/

# %%
final_combined_df = pd.concat(combined_dataframes, ignore_index=True)
final_study_info = pd.DataFrame(study_info_general)
final_combined_df.to_csv('/Users/demidenm/Downloads/final_study_combined_checks.tsv', sep='\t')
final_study_info.to_csv('/Users/demidenm/Downloads/final_study_details.tsv', sep='\t')

# %% [markdown]
# # Plotting some results from combined evevts + study info

# %%
final_combined_df = pd.read_csv('/Users/demidenm/Downloads/final_study_combined_checks.tsv', sep='\t', low_memory=False)
final_study_info = pd.read_csv('/Users/demidenm/Downloads/final_study_details.tsv', sep='\t', low_memory=False)

# %%
final_study_info.columns
# Out:
# Index(['Unnamed: 0', 'study_name', 'num_subs', 'nuum_sess', 'num_runs',
#        'bold_exists', 'nonrest_exists', 'num_non-rest_tasks', 'task_list',
#        'task_decsriptor_exist', 'datadesc_exist', 'partic_json_exist',
#        'participant_tsv_exist', 'error_messages'],
#       dtype='object')

# %%
total_n = len(final_study_info)
bids_layouterror = final_study_info['error_messages'].notna().sum() / total_n
bold_proportion = final_study_info['bold_exists'].sum() / total_n
nonrest_proportion = final_study_info['nonrest_exists'].sum() / total_n
task_descr_exist = final_study_info['task_decsriptor_exist'].dropna().apply(lambda x: any(x)).astype(bool).sum() / total_n

plt.bar(['BOLD Exists', 'Non-Rest Exists', 'Task Descriptor Exists', 'BIDSLayout Errors'], 
        [bold_proportion, nonrest_proportion, task_descr_exist, bids_layouterror])
plt.ylabel('Proportion')
plt.title(f'Proportion of N {len(final_study_info)} OpenNeuro Studies Have BOLD, Non-Rest Tasks, \n Task Descriptor or BIDSLayout Error')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
datdesc_proportion = final_study_info['datadesc_exist'].sum() / total_n
partici_json_proportion = final_study_info['partic_json_exist'].sum() / total_n
participant_tsv_proportion = final_study_info['participant_tsv_exist'].sum() / total_n

plt.bar(['Data Desc Exists', 'Part. TSV Exist', 'Part. JSON Exist', ],
        [datdesc_proportion, participant_tsv_proportion, partici_json_proportion])
plt.ylabel('Proportion')
plt.title(f'Proportion of N {len(final_study_info)} OpenNeuro Studies Have \n Data Descriptor and Participant Files')
plt.ylim(0, 1)
plt.tight_layout()
plt.show()

# %%
filtered_data = final_study_info[final_study_info['nonrest_exists'] == True]

plt.hist(filtered_data['num_subs'], bins=500)
max_subs = filtered_data['num_subs'].max()
max_label = filtered_data.loc[filtered_data['num_subs'] == max_subs, 'study_name'].values[0]
plt.axvline(max_subs, color='r', linestyle='--')
plt.text(max_subs-200, plt.ylim()[1]*0.95, f'{max_label}', color='r')
plt.xlim(0,1300)
plt.title(f'Age Across OpenNeuro BOLD Datasets \n Median N = {filtered_data["num_subs"].median()}')
plt.tight_layout()
plt.show()

# %%
filtered_data['nuum_sess'] = filtered_data['nuum_sess'].fillna(0).astype(int)

plt.hist(filtered_data['nuum_sess'], bins=50)
max_sess = filtered_data['nuum_sess'].max()
max_label = filtered_data.loc[filtered_data['nuum_sess'] == max_sess, 'study_name'].values[0]
plt.xlim(0,80)
plt.axvline(max_sess, color='r', linestyle='--')
plt.text(max_sess-10, plt.ylim()[1]*0.95, f'{max_label}', color='r')

plt.title(f'Sessions Across OpenNeuro BOLD Datasets \n Median N = {filtered_data["nuum_sess"].median()}')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/nx/gcr6rtnn7l78fw142ttl01d00000gn/T/ipykernel_54522/2832325334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['nuum_sess'] = filtered_data['nuum_sess'].fillna(0).astype(int)

# %%
filtered_data['num_runs'] = filtered_data['num_runs'].fillna(0).astype(int)

plt.hist(filtered_data['num_runs'], bins=500)
max_run = filtered_data['num_runs'].max()
max_label = filtered_data.loc[filtered_data['num_runs'] == max_run, 'study_name'].values[0]
plt.xlim(0,20)
plt.title(f'Runs Across OpenNeuro BOLD Datasets \n Mean N = {filtered_data["num_runs"].mean().round(1)}')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/nx/gcr6rtnn7l78fw142ttl01d00000gn/T/ipykernel_54522/2609117738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['num_runs'] = filtered_data['num_runs'].fillna(0).astype(int)

# %%
check_levels_miss_str = 'Levels key missing in data descriptor'
string_levels_col = 'string_unique_in_levels'
missing_levels_df = final_combined_df[(final_combined_df['data_type'] == 'object') & (final_combined_df['column_in_descriptor'] == True)]
missing_levels_df = missing_levels_df[
    ~(
        missing_levels_df['events_column'].str.contains('path|file', case=False, na=False) |
        missing_levels_df['string_unique'].str.contains('\.bmp|\.jpg|\.wav', case=False, na=False)
    )
]

missing_levels_df[string_levels_col].apply(lambda x: x == check_levels_miss_str).sum() / len(missing_levels_df)
# Out:
# 0.6833699998086966

# %%
col_descr_df = final_combined_df[
    ~(
        final_combined_df['events_column'].str.contains('path|file', case=False, na=False) |
        final_combined_df['string_unique'].str.contains('\.bmp|\.jpg|\.wav', case=False, na=False)
    )
]

col_descrfalse_df = final_combined_df[final_combined_df['column_in_descriptor'] == False]
col_descrfalse_df = col_descrfalse_df[
    ~(
        col_descrfalse_df['events_column'].str.contains('path|file', case=False, na=False) |
        col_descrfalse_df['string_unique'].str.contains('\.bmp|\.jpg|\.wav', case=False, na=False)
    )
]

# %%
study_ids = missing_levels_df['study'].unique()

prop_misslevels_df = []

for op_study in study_ids:
    study_subs = missing_levels_df[missing_levels_df['study'] == op_study]['subject'].unique()
    rand_sub = random.choice(study_subs)



    sub_vals = missing_levels_df[
        (missing_levels_df['study'] == op_study) &
        (missing_levels_df['subject'] == rand_sub)
    ]
    prop_miss_levels = sub_vals[string_levels_col].apply(lambda x: 
                                                         x == check_levels_miss_str).sum() / len(sub_vals)
    prop_misslevels_df.append(prop_miss_levels)

# %%
study_ids = col_descr_df['study'].unique()
prop_missldescr_df = []
for op_study in study_ids:
    study_subs = col_descr_df[col_descr_df['study'] == op_study]['subject'].unique()
    rand_sub = random.choice(study_subs)

    sub_vals = col_descr_df[
        (col_descr_df['study'] == op_study) &
        (col_descr_df['subject'] == rand_sub)
    ]
    prop_miss_decsr = sub_vals['column_in_descriptor'].apply(lambda x: 
                                                         x == False).sum() / len(sub_vals)
    prop_missldescr_df.append(prop_miss_decsr)

# %%
plt.figure(figsize=(20, 10))
sns.histplot(data=prop_missldescr_df, palette='viridis')
plt.title(f'For One Random Subject Across {len(study_ids)} Studies, \n Proportion Column From Events Not in Task Descriptor ')
plt.xticks(rotation=90)
plt.xlabel('Freq (N)')
plt.ylabel('Inputs')
plt.show()
# Out:
# /var/folders/nx/gcr6rtnn7l78fw142ttl01d00000gn/T/ipykernel_54522/3950480675.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=prop_missldescr_df, palette='viridis')

# %%
plt.figure(figsize=(20, 10))
sns.histplot(data=prop_misslevels_df, palette='viridis')
plt.title(f'For One Random Subject Across {len(study_ids)} Studies, \n Proportion Unique Strs Not Defined In Task Descriptor Lvls')
plt.xticks(rotation=90)
plt.xlabel('Freq (N)')
plt.ylabel('Inputs')
plt.show()
# Out:
# /var/folders/nx/gcr6rtnn7l78fw142ttl01d00000gn/T/ipykernel_54522/3062419620.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=prop_misslevels_df, palette='viridis')

# %%
def select_random_subject(df):
    selected_subjects = df.groupby('study')['subject'].apply(lambda x: x.sample(n=1).values[0])
    filtered_df = df[df['subject'].isin(selected_subjects)]
    return filtered_df
col_descr_subsetdf = select_random_subject(col_descr_df)

freq_words = Counter(col_descr_subsetdf['string_unique'])

# pick top 100
top_words = dict(freq_words.most_common(100))

top_words_df = pd.DataFrame(list(top_words.items()), columns=['name', 'freq'])

#plt 
plt.figure(figsize=(20, 10))
sns.barplot(data=top_words_df, x='name', y='freq', palette='viridis')
plt.title(f'For one Subject from Each Dataset \n Frequency in `string_unique` across {len(col_descr_subsetdf)} rows')
plt.xticks(rotation=90)
plt.xlabel('Freq (N)')
plt.ylabel('Inputs')
plt.show()

# %%
freq_words = Counter(missing_levels_df['events_column'])

# pick top 50
top_words = dict(freq_words.most_common(50))

top_words_df = pd.DataFrame(list(top_words.items()), columns=['name', 'freq'])

#plt 
plt.figure(figsize=(12, 8))
sns.barplot(data=top_words_df, y='name', x='freq', palette='viridis')
plt.title(f'DF For Object Data-types Levels == Missing in Descriptor \n Events Column Names Frequencies Across {len(missing_levels_df)} rows')
plt.xlabel('Freq (N)')
plt.ylabel('Inputs')
plt.show()

# %%
freq_words = Counter(col_descr_df['events_column'])

# pick top 50
top_words = dict(freq_words.most_common(50))

top_words_df = pd.DataFrame(list(top_words.items()), columns=['name', 'freq'])

#plt 
plt.figure(figsize=(12, 8))
sns.barplot(data=top_words_df, y='name', x='freq', palette='viridis')
plt.title(f'Events Column Names Frequencies Across {len(col_descr_df)} rows')
plt.xlabel('Freq (N)')
plt.ylabel('Inputs')
plt.show()

# %%
freq_words = Counter(col_descrfalse_df['events_column'])

# pick top 50
top_words = dict(freq_words.most_common(50))

top_words_df = pd.DataFrame(list(top_words.items()), columns=['name', 'freq'])

#plt 
plt.figure(figsize=(12, 8))
sns.barplot(data=top_words_df, y='name', x='freq', palette='viridis')
plt.title(f'When Events Column Name is NOT in Descriptor \n Frequencies Across {len(col_descrfalse_df)} rows ')
plt.xlabel('Freq (N)')
plt.ylabel('Inputs')
plt.show()

# %% [markdown]
# # Test odd outputs

# %%
tst_df = '/Users/demidenm/Desktop/Academia/Stanford/9_ResearchSci/OpenNeuro/data/openneuro/ds002674/'
tst_layout = BIDSLayout(tst_df)

# %%
tst_layout.get_sessions(), tst_layout.get_runs()
# Out:
# (['01',
#   '06',
#   '56',
#   '08',
#   '27',
#   '10',
#   '18',
#   '19',
#   '51',
#   '39',
#   '50',
#   '33',
#   '52',
#   '35',
#   '38',
#   '47',
#   '11',
#   '05',
#   '07',
#   '24',
#   '44',
#   '36',
#   '46',
#   '21',
#   '29',
#   '25',
#   '02',
#   '03',
#   '13',
#   '49',
#   '32',
#   '12',
#   '37',
#   '43',
#   '30',
#   '45',
#   '54',
#   '26',
#   '48',
#   '17',
#   '31',
#   '55',
#   '58',
#   '23',
#   '60',
#   '22',
#   '16',
#   '59',
#   '40',
#   '34',
#   '04',
#   '42',
#   '53',
#   '09',
#   '41',
#   '20',
#   '28',
#   '57',
#   '14',
#   '15'],
#  [])
